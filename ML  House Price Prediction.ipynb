# %% [markdown]
# ***Author: Aryan Jayswal***

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import warnings
warnings.simplefilter(action='ignore', category=Warning)

# %%
# Load the given dataset
df  = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\ML project  2\Python_Linear_Regres.csv")

# %%
df.head(5)
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
# Print all the column names
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
#  Describe the data
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
# Drop address, date, postcode, YearBuilt, lattitude, longtitude columns
df.drop(columns=["Suburb","Address","Date","Postcode","YearBuilt","Lattitude","Longtitude","CouncilArea","Regionname","Propertycount"],inplace=True )

# %%
df.columns
# Out:
# Index(['Rooms', 'Type', 'Price', 'Method', 'SellerG', 'Distance', 'Bedroom2',
#        'Bathroom', 'Car', 'Landsize', 'BuildingArea'],
#       dtype='object')

# %%
#  count of null value in each column 
df.isnull().sum()
# Out:
# Rooms               0
# Type                0
# Price            7610
# Method              0
# SellerG             0
# Distance            1
# Bedroom2         8217
# Bathroom         8226
# Car              8728
# Landsize        11810
# BuildingArea    21115
# dtype: int64

# %% [markdown]
# ***Fill the null value of property count, distance, Bedroom2, Bathroom, Car with 0***

# %%
df["Distance"].fillna(0,inplace=True)

# %%
df["Bedroom2"].fillna(0,inplace=True)

# %%
df["Bathroom"].fillna(0,inplace=True)

# %%
df["Car"].fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Rooms               0
# Type                0
# Price            7610
# Method              0
# SellerG             0
# Distance            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize        11810
# BuildingArea    21115
# dtype: int64

# %% [markdown]
# ***Fill Null value of land size and bidding area columns with Mean***

# %%
df["Landsize"].fillna(df["Landsize"].mean(),inplace=True)

# %%
df["BuildingArea"].fillna(df["BuildingArea"].mean(),inplace=True)

# %%
df["Bathroom"].fillna(df["Bathroom"].mean(),inplace=True)

# %%
df.dropna(subset=["Price"],inplace=True)

# %%
df.isnull().sum()
# Out:
# Rooms           0
# Type            0
# Price           0
# Method          0
# SellerG         0
# Distance        0
# Bedroom2        0
# Bathroom        0
# Car             0
# Landsize        0
# BuildingArea    0
# dtype: int64

# %%
df["Method"].unique()
# Out:
# array(['S', 'SP', 'PI', 'VB', 'SA'], dtype=object)

# %%
df.head()
# Out:
#    Rooms Type      Price Method SellerG  Distance  Bedroom2  Bathroom  Car  \
# 1      2    h  1480000.0      S  Biggin       2.5       2.0       1.0  1.0
# 2      2    h  1035000.0      S  Biggin       2.5       2.0       1.0  0.0
# 4      3    h  1465000.0     SP  Biggin       2.5       3.0       2.0  0.0
# 5      3    h   850000.0     PI  Biggin       2.5       3.0       2.0  1.0
# 6      4    h  1600000.0     VB  Nelson       2.5       3.0       1.0  2.0
#
#    Landsize  BuildingArea
# 1     202.0      160.2564
# 2     156.0       79.0000
# 4     134.0      150.0000
# 5      94.0      160.2564
# 6     120.0      142.0000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df["Type"] = lb.fit_transform(df["Type"])

# %%
df["Method"] = lb.fit_transform(df["Method"])

# %%
df["SellerG"] = lb.fit_transform(df["SellerG"])

# %%
df
# Out:
#        Rooms  Type      Price  Method  SellerG  Distance  Bedroom2  Bathroom  \
# 1          2     0  1480000.0       1       32       2.5       2.0       1.0
# 2          2     0  1035000.0       1       32       2.5       2.0       1.0
# 4          3     0  1465000.0       3       32       2.5       3.0       2.0
# 5          3     0   850000.0       0       32       2.5       3.0       2.0
# 6          4     0  1600000.0       4      206       2.5       3.0       1.0
# ...      ...   ...        ...     ...      ...       ...       ...       ...
# 34852      4     0  1480000.0       0      140       6.3       4.0       1.0
# 34853      2     0   888000.0       3      290       6.3       2.0       2.0
# 34854      2     1   705000.0       1      140       6.3       2.0       1.0
# 34855      3     0  1140000.0       3      334       6.3       0.0       0.0
# 34856      2     0  1020000.0       0      252       6.3       2.0       1.0
#
#        Car    Landsize  BuildingArea
# ...

# %% [markdown]
# ***Part-2: Working with Model***

# %%
# Create the target data and feature data where target data is price
x = df.drop(columns="Price")
y = df["Price"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 39.18307433478982

# %%
lr.score(x_train,y_train)*100
# Out:
# 41.49401462396804

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
import numpy as np

# %%
y_pred = lr.predict(x_test)

# %%
MAE = mean_absolute_error(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
R2SCORE = r2_score(y_test,y_pred)*100

print("MAE =",MAE)
print("MSE", MSE)
print("R2 Score",R2SCORE)
# Out:
# MAE = 334804.9855685793
# MSE 259876624513.75668
# R2 Score 39.18307433478982

# %%
from sklearn.linear_model import Ridge, Lasso

# Ridge Regression
ridge = Ridge(alpha=1.0)
ridge.fit(x_train, y_train)
ridge_pred = ridge.predict(x_test)
print("Ridge R2 Score:", r2_score(y_test, ridge_pred)*100)
# Out:
# Ridge R2 Score: 39.18281604792239

# %%
# lasso regression 
lasso = Lasso(alpha=1.0)
lasso.fit(x_train,y_train)
lasso_predict = lasso.predict(x_test)
print("Lasso R2 score",r2_score(y_test,lasso_predict)*100)
# Out:
# Lasso R2 score 39.18304764247701
